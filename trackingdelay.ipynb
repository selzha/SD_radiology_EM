# %%
import numpy as np
import pandas as pd
from pupil_functions import *

# %% [markdown]
# ## test

# %%
col = ["block", "trial", "task", "sent", "received"]
times000 = pd.DataFrame(columns = col)

# %%
df000 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/test/003")

# %%
#change none's to nearest numbers
for idx, num in df000.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df000.iloc[point, 4]
            if val is not None:
                df000.set_value(idx, "trial", val)
                break
#first two must be manually done
df000.set_value(0, "trial", 1)
df000.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df000.iterrows():
    #only did first 13 trials
    if float(df000.iloc[idx, 4]) > 13:
        break
    #fixation
    if df000.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = df000.iloc[idx, 4]
        block = df000.iloc[idx, 0]
        sent = df000.iloc[idx, 3]
        if df000.iloc[idx + 1, 1] == "fix":
            received = df000.iloc[idx + 1, 3]
        else:
            received = df000.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times000.loc[len(times000), :] = row
    #image onset
    elif df000.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = df000.iloc[idx, 4]
        block = df000.iloc[idx, 0]
        sent = df000.iloc[idx, 3]
        if df000.iloc[idx + 1, 1] == "image_onset":
            received = df000.iloc[idx + 1, 3]
        else:
            received = df000.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        times000.loc[len(times000), :] = row
    elif df000.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = df000.iloc[idx, 4]
        block = df000.iloc[idx, 0]
        sent = df000.iloc[idx, 3]
        if df000.iloc[idx + 1, 1] == "adjust":
            received = df000.iloc[idx + 1, 3]
        else:
            received = df000.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times000.loc[len(times000), :] = row
    else:
        pass

# %%
#find differences
times000["delay"] = times000["sent"] - times000["received"]

# %%
times000
# Out:
#    block trial          task         sent     received     delay
# 0      1     1  Fixation dot  1.58386e+09  1.58386e+09  -0.27266
# 1      1     1   Image onset  1.58386e+09  1.58386e+09 -0.410035
# 2      1     1   Adjust task  1.58386e+09  1.58386e+09 -0.193321
# 3      1     2  Fixation dot  1.58386e+09  1.58386e+09 -0.251293
# 4      1     2   Image onset  1.58386e+09  1.58386e+09 -0.360672
# 5      1     2   Adjust task  1.58386e+09  1.58386e+09 -0.257875
# 6      1     3  Fixation dot  1.58386e+09  1.58386e+09  -0.66969
# 7      1     3   Image onset  1.58386e+09  1.58386e+09 -0.333822
# 8      1     3   Adjust task  1.58386e+09  1.58386e+09 -0.275162
# 9      1     4  Fixation dot  1.58386e+09  1.58386e+09  -0.30266
# 10     1     4   Image onset  1.58386e+09  1.58386e+09 -0.290056
# 11     1     4   Adjust task  1.58386e+09  1.58386e+09 -0.207635
# 12     1     5  Fixation dot  1.58386e+09  1.58386e+09 -0.240622
# ...

# %%
avg = times000["delay"].mean()

# %%
if avg < 0:
    times000["fixedlag"] = times000["received"] + avg #avg was negative
elif avg > 0:
    times000["fixedlag"] = times000["received"] - avg

# %%
times000
# Out:
#    block trial          task         sent     received     delay     fixedlag
# 0      1     1  Fixation dot  1.58386e+09  1.58386e+09  -0.27266  1.58386e+09
# 1      1     1   Image onset  1.58386e+09  1.58386e+09 -0.410035  1.58386e+09
# 2      1     1   Adjust task  1.58386e+09  1.58386e+09 -0.193321  1.58386e+09
# 3      1     2  Fixation dot  1.58386e+09  1.58386e+09 -0.251293  1.58386e+09
# 4      1     2   Image onset  1.58386e+09  1.58386e+09 -0.360672  1.58386e+09
# 5      1     2   Adjust task  1.58386e+09  1.58386e+09 -0.257875  1.58386e+09
# 6      1     3  Fixation dot  1.58386e+09  1.58386e+09  -0.66969  1.58386e+09
# 7      1     3   Image onset  1.58386e+09  1.58386e+09 -0.333822  1.58386e+09
# 8      1     3   Adjust task  1.58386e+09  1.58386e+09 -0.275162  1.58386e+09
# 9      1     4  Fixation dot  1.58386e+09  1.58386e+09  -0.30266  1.58386e+09
# 10     1     4   Image onset  1.58386e+09  1.58386e+09 -0.290056  1.58386e+09
# ...

# %% [markdown]
# ## subject 1

# %%
times001 = pd.DataFrame(columns = col)
df001 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subject1/001")

# %%
#change none's to nearest numbers
for idx, num in df001.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df001.iloc[point, 4]
            if val is not None:
                df001.set_value(idx, "trial", val)
                break
#first two must be manually done
df001.set_value(0, "trial", 1)
df001.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df001.iterrows():
    #first 10
    if float(df001.iloc[idx, 4]) > 10:
        break
    #fixation
    if df001.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = df001.iloc[idx, 4]
        block = df001.iloc[idx, 0]
        sent = df001.iloc[idx, 3]
        if df001.iloc[idx + 1, 1] == "fix":
            received = df001.iloc[idx + 1, 3]
        else:
            received = df001.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times001.loc[len(times001), :] = row
    #image onset
    elif df001.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = df001.iloc[idx, 4]
        block = df001.iloc[idx, 0]
        sent = df001.iloc[idx, 3]
        if df001.iloc[idx + 1, 1] == "image_onset":
            received = df001.iloc[idx + 1, 3]
        else:
            received = df001.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        times001.loc[len(times001), :] = row
    elif df001.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = df001.iloc[idx, 4]
        block = df001.iloc[idx, 0]
        sent = df001.iloc[idx, 3]
        if df001.iloc[idx + 1, 1] == "adjust":
            received = df001.iloc[idx + 1, 3]
        else:
            received = df001.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times001.loc[len(times001), :] = row
    else:
        pass

# %%
times001["delay"] = times001["sent"] - times001["received"]

# %%
avg = times001["delay"].mean()
if avg < 0:
    times001["fixedlag"] = times001["received"] + avg #avg was negative
elif avg > 0:
    times001["fixedlag"] = times001["received"] - avg

# %%
times001
# Out:
#    block trial          task        sent    received        delay    fixedlag
# 0      1     1  Fixation dot  1.5754e+09  1.5754e+09    -0.268816  1.5754e+09
# 1      1     1   Image onset  1.5754e+09  1.5754e+09    -0.144623  1.5754e+09
# 2      1     1   Adjust task  1.5754e+09  1.5754e+09    0.0225048  1.5754e+09
# 3      1     2  Fixation dot  1.5754e+09  1.5754e+09  -0.00954509  1.5754e+09
# 4      1     2   Image onset  1.5754e+09  1.5754e+09   -0.0857191  1.5754e+09
# 5      1     2   Adjust task  1.5754e+09  1.5754e+09   0.00772476  1.5754e+09
# 6      1     3  Fixation dot  1.5754e+09  1.5754e+09  0.000129223  1.5754e+09
# 7      1     3   Image onset  1.5754e+09  1.5754e+09   -0.0300572  1.5754e+09
# 8      1     3   Adjust task  1.5754e+09  1.5754e+09    0.0183897  1.5754e+09
# 9      1     4  Fixation dot  1.5754e+09  1.5754e+09   -0.0117464  1.5754e+09
# 10     1     4   Image onset  1.5754e+09  1.5754e+09   -0.0544591  1.5754e+09
# ...

# %% [markdown]
# ## subject 2
# invalid recording

# %% [markdown]
# ## subject 3
# grey. no world.mp4

# %% [markdown]
# ## subject 4
# grey. no world.mp4

# %% [markdown]
# ## subject 5
# grey. no world.mp4

# %% [markdown]
# ## subject 6

# %%
times006 = pd.DataFrame(columns = col)
df006 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subject6/001")

# %%
#change none's to nearest numbers
for idx, num in df006.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df006.iloc[point, 4]
            if val is not None:
                df006.set_value(idx, "trial", val)
                break
#first two must be manually done
df006.set_value(0, "trial", 1)
df006.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df006.iterrows():
    #12-22 trials
    if float(df006.iloc[idx, 4]) > 22:
        break
    if float(df006.iloc[idx, 4]) < 12:
        pass
    else: 
        #fixation
        if df006.iloc[idx, 2] == "Fixation dot":
            task = "Fixation dot"
            trial = df006.iloc[idx, 4]
            block = df006.iloc[idx, 0]
            sent = df006.iloc[idx, 3]
            if df006.iloc[idx + 1, 1] == "fix":
                received = df006.iloc[idx + 1, 3]
            else:
                received = df006.iloc[idx - 1, 3]
            row = [block, trial, task, sent, received]
            times006.loc[len(times006), :] = row
        #image onset
        elif df006.iloc[idx, 2] == "Image onset":
            task = "Image onset"
            trial = df006.iloc[idx, 4]
            block = df006.iloc[idx, 0]
            sent = df006.iloc[idx, 3]
            if df006.iloc[idx + 1, 1] == "image_onset":
                received = df006.iloc[idx + 1, 3]
            else:
                received = df006.iloc[idx - 1, 3]        
            row = [block, trial, task, sent, received]
            times006.loc[len(times006), :] = row
        elif df006.iloc[idx, 2] == "Adjust task":
            task = "Adjust task"
            trial = df006.iloc[idx, 4]
            block = df006.iloc[idx, 0]
            sent = df006.iloc[idx, 3]
            if df006.iloc[idx + 1, 1] == "adjust":
                received = df006.iloc[idx + 1, 3]
            else:
                received = df006.iloc[idx - 1, 3]
            row = [block, trial, task, sent, received]
            times006.loc[len(times006), :] = row
        else:
            pass

# %%
times006["delay"] = times006["sent"] - times006["received"]

# %%
avg = times006["delay"].mean()
if avg < 0:
    times006["fixedlag"] = times006["received"] + avg #avg was negative
elif avg > 0:
    times006["fixedlag"] = times006["received"] - avg

# %%
times006
# Out:
#    block trial          task         sent     received       delay  \
# 0      1    12  Fixation dot  1.57547e+09  1.57547e+09  -0.0223918
# 1      1    12   Image onset  1.57547e+09  1.57547e+09   -0.561334
# 2      1    12   Adjust task  1.57547e+09  1.57547e+09  -0.0168476
# 3      1    13  Fixation dot  1.57547e+09  1.57547e+09  -0.0406237
# 4      1    13   Image onset  1.57547e+09  1.57547e+09   -0.111457
# 5      1    13   Adjust task  1.57547e+09  1.57547e+09 -0.00608873
# 6      1    14  Fixation dot  1.57547e+09  1.57547e+09  -0.0420337
# 7      1    14   Image onset  1.57547e+09  1.57547e+09  -0.0882907
# 8      1    14   Adjust task  1.57547e+09  1.57547e+09 -0.00637579
# 9      1    15  Fixation dot  1.57547e+09  1.57547e+09  -0.0232928
# 10     1    15   Image onset  1.57547e+09  1.57547e+09   -0.116098
# 11     1    15   Adjust task  1.57547e+09  1.57547e+09  0.00558734
# 12     1    16  Fixation dot  1.57547e+09  1.57547e+09  -0.0213866
# ...

# %% [markdown]
# ## subject 7
# screen was all white

# %% [markdown]
# ## subject 8

# %%
times008 = pd.DataFrame(columns = col)
df008 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subject8/001")

# %%
#change none's to nearest numbers
for idx, num in df008.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df008.iloc[point, 4]
            if val is not None:
                df008.set_value(idx, "trial", val)
                break
#first two must be manually done
df008.set_value(0, "trial", 1)
df008.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df008.iterrows():
    #10 trials
    if float(df008.iloc[idx, 4]) > 10:
        break
    #fixation
    if df008.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = df008.iloc[idx, 4]
        block = df008.iloc[idx, 0]
        sent = df008.iloc[idx, 3]
        if df008.iloc[idx + 1, 1] == "fix":
            received = df008.iloc[idx + 1, 3]
        else:
            received = df008.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times008.loc[len(times008), :] = row
    #image onset
    elif df008.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = df008.iloc[idx, 4]
        block = df008.iloc[idx, 0]
        sent = df008.iloc[idx, 3]
        if df008.iloc[idx + 1, 1] == "image_onset":
            received = df008.iloc[idx + 1, 3]
        else:
            received = df008.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        times008.loc[len(times008), :] = row
    elif df008.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = df008.iloc[idx, 4]
        block = df008.iloc[idx, 0]
        sent = df008.iloc[idx, 3]
        if df008.iloc[idx + 1, 1] == "adjust":
            received = df008.iloc[idx + 1, 3]
        else:
            received = df008.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times008.loc[len(times008), :] = row
    else:
        pass

# %%
times008["delay"] = times008["sent"] - times008["received"]

# %%
avg = times008["delay"].mean()
if avg < 0:
    times008["fixedlag"] = times008["received"] + avg #avg was negative
elif avg > 0:
    times008["fixedlag"] = times008["received"] - avg

# %%
times008
# Out:
#    block trial          task         sent     received        delay  \
# 0      1     1  Fixation dot  1.57548e+09  1.57548e+09    -0.103712
# 1      1     1   Image onset  1.57548e+09  1.57548e+09     -0.29923
# 2      1     1   Adjust task  1.57548e+09  1.57548e+09   0.00462127
# 3      1     2  Fixation dot  1.57548e+09  1.57548e+09   -0.0375497
# 4      1     2   Image onset  1.57548e+09  1.57548e+09   -0.0579817
# 5      1     2   Adjust task  1.57548e+09  1.57548e+09   -0.0034709
# 6      1     3  Fixation dot  1.57548e+09  1.57548e+09   -0.0360188
# 7      1     3   Image onset  1.57548e+09  1.57548e+09   -0.0940757
# 8      1     3   Adjust task  1.57548e+09  1.57548e+09   -0.0187206
# 9      1     4  Fixation dot  1.57548e+09  1.57548e+09   -0.0289826
# 10     1     4   Image onset  1.57548e+09  1.57548e+09   -0.0458956
# 11     1     4   Adjust task  1.57548e+09  1.57548e+09   0.00567102
# 12     1     5  Fixation dot  1.57548e+09  1.57548e+09   -0.0336587
# ...

# %% [markdown]
# ## subject 9
# black screen

# %% [markdown]
# ## subject 10
# black screen

# %% [markdown]
# ## subject 11

# %%
times011 = pd.DataFrame(columns = col)
df011 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subject11/001")

# %%
#change none's to nearest numbers
for idx, num in df011.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df011.iloc[point, 4]
            if val is not None:
                df011.set_value(idx, "trial", val)
                break
#first two must be manually done
df011.set_value(0, "trial", 1)
df011.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df011.iterrows():
   #first 10 trials
    if float(df011.iloc[idx, 4]) > 10:
        break
    #fixation
    if df011.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = df011.iloc[idx, 4]
        block = df011.iloc[idx, 0]
        sent = df011.iloc[idx, 3]
        if df011.iloc[idx + 1, 1] == "fix":
            received = df011.iloc[idx + 1, 3]
        else:
            received = df011.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times011.loc[len(times011), :] = row
    #image onset
    elif df011.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = df011.iloc[idx, 4]
        block = df011.iloc[idx, 0]
        sent = df011.iloc[idx, 3]
        if df011.iloc[idx + 1, 1] == "image_onset":
            received = df011.iloc[idx + 1, 3]
        else:
            received = df011.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        times011.loc[len(times011), :] = row
    elif df011.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = df011.iloc[idx, 4]
        block = df011.iloc[idx, 0]
        sent = df011.iloc[idx, 3]
        if df011.iloc[idx + 1, 1] == "adjust":
            received = df011.iloc[idx + 1, 3]
        else:
            received = df011.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times011.loc[len(times011), :] = row
    else:
        pass

# %%
times011["delay"] = times011["sent"] - times011["received"]

# %%
avg = times011["delay"].mean()
if avg < 0:
    times011["fixedlag"] = times011["received"] + avg #avg was negative
elif avg > 0:
    times011["fixedlag"] = times011["received"] - avg

# %%
times011
# Out:
#    block trial          task         sent     received        delay  \
# 0      1     1  Fixation dot  1.57549e+09  1.57549e+09   -0.0875642
# 1      1     1   Image onset  1.57549e+09  1.57549e+09    -0.207674
# 2      1     1   Adjust task  1.57549e+09  1.57549e+09  -0.00892615
# 3      1     2  Fixation dot  1.57549e+09  1.57549e+09    -0.053983
# 4      1     2   Image onset  1.57549e+09  1.57549e+09    -0.103395
# 5      1     2   Adjust task  1.57549e+09  1.57549e+09   -0.0204813
# 6      1     3  Fixation dot  1.57549e+09  1.57549e+09   -0.0442541
# 7      1     3   Image onset  1.57549e+09  1.57549e+09    -0.076539
# 8      1     3   Adjust task  1.57549e+09  1.57549e+09   0.00516391
# 9      1     4  Fixation dot  1.57549e+09  1.57549e+09   -0.0450261
# 10     1     4   Image onset  1.57549e+09  1.57549e+09   -0.0559142
# 11     1     4   Adjust task  1.57549e+09  1.57549e+09   -0.0262423
# 12     1     5  Fixation dot  1.57549e+09  1.57549e+09   -0.0165501
# ...

# %% [markdown]
# ## subject 12

# %%
times012 = pd.DataFrame(columns = col)
df012 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subject12/001")

# %%
#change none's to nearest numbers
for idx, num in df012.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df012.iloc[point, 4]
            if val is not None:
                df012.set_value(idx, "trial", val)
                break
#first two must be manually done
df012.set_value(0, "trial", 1)
df012.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df012.iterrows():
#10 trials
    if float(df012.iloc[idx, 4]) > 10:
        break
    #fixation
    if df012.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = df012.iloc[idx, 4]
        block = df012.iloc[idx, 0]
        sent = df012.iloc[idx, 3]
        if df012.iloc[idx + 1, 1] == "fix":
            received = df012.iloc[idx + 1, 3]
        else:
            received = df012.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times012.loc[len(times012), :] = row
    #image onset
    elif df012.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = df012.iloc[idx, 4]
        block = df012.iloc[idx, 0]
        sent = df012.iloc[idx, 3]
        if df012.iloc[idx + 1, 1] == "image_onset":
            received = df012.iloc[idx + 1, 3]
        else:
            received = df012.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        times012.loc[len(times012), :] = row
    elif df012.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = df012.iloc[idx, 4]
        block = df012.iloc[idx, 0]
        sent = df012.iloc[idx, 3]
        if df012.iloc[idx + 1, 1] == "adjust":
            received = df012.iloc[idx + 1, 3]
        else:
            received = df012.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times012.loc[len(times012), :] = row
    else:
        pass

# %%
times012["delay"] = times012["sent"] - times012["received"]

# %%
avg = times012["delay"].mean()
if avg < 0:
    times012["fixedlag"] = times012["received"] + avg #avg was negative
elif avg > 0:
    times012["fixedlag"] = times012["received"] - avg

# %%
times012
# Out:
#    block trial          task         sent     received       delay  \
# 0      1     1  Fixation dot  1.57556e+09  1.57556e+09   -0.217311
# 1      1     1   Image onset  1.57556e+09  1.57556e+09   -0.129316
# 2      1     1   Adjust task  1.57556e+09  1.57556e+09  -0.0349123
# 3      1     2  Fixation dot  1.57556e+09  1.57556e+09  -0.0383961
# 4      1     2   Image onset  1.57556e+09  1.57556e+09   -0.084779
# 5      1     2   Adjust task  1.57556e+09  1.57556e+09 -0.00626206
# 6      1     3  Fixation dot  1.57556e+09  1.57556e+09  -0.0396373
# 7      1     3   Image onset  1.57556e+09  1.57556e+09  -0.0996952
# 8      1     3   Adjust task  1.57556e+09  1.57556e+09  0.00974202
# 9      1     4  Fixation dot  1.57556e+09  1.57556e+09  -0.0195522
# 10     1     4   Image onset  1.57556e+09  1.57556e+09  -0.0485671
# 11     1     4   Adjust task  1.57556e+09  1.57556e+09 -0.00261807
# 12     1     5  Fixation dot  1.57556e+09  1.57556e+09   -0.018008
# ...

# %% [markdown]
# ## subject 13
# black screen

# %% [markdown]
# ## subject 14

# %%
times014 = pd.DataFrame(columns = col)
df014 = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subject12/001")

# %%
#change none's to nearest numbers
for idx, num in df014.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = df014.iloc[point, 4]
            if val is not None:
                df014.set_value(idx, "trial", val)
                break
#first two must be manually done
df014.set_value(0, "trial", 1)
df014.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in df014.iterrows():
#10 trials
    if float(df014.iloc[idx, 4]) > 10:
        break
    #fixation
    if df014.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = df014.iloc[idx, 4]
        block = df014.iloc[idx, 0]
        sent = df014.iloc[idx, 3]
        if df014.iloc[idx + 1, 1] == "fix":
            received = df014.iloc[idx + 1, 3]
        else:
            received = df014.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times014.loc[len(times014), :] = row
    #image onset
    elif df014.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = df014.iloc[idx, 4]
        block = df014.iloc[idx, 0]
        sent = df014.iloc[idx, 3]
        if df014.iloc[idx + 1, 1] == "image_onset":
            received = df014.iloc[idx + 1, 3]
        else:
            received = df014.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        times014.loc[len(times014), :] = row
    elif df014.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = df014.iloc[idx, 4]
        block = df014.iloc[idx, 0]
        sent = df014.iloc[idx, 3]
        if df014.iloc[idx + 1, 1] == "adjust":
            received = df014.iloc[idx + 1, 3]
        else:
            received = df014.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        times014.loc[len(times014), :] = row
    else:
        pass

# %%
times014["delay"] = times014["sent"] - times014["received"]

# %%
avg = times014["delay"].mean()
if avg < 0:
    times014["fixedlag"] = times014["received"] + avg #avg was negative
elif avg > 0:
    times014["fixedlag"] = times014["received"] - avg

# %%
times014
# Out:
#    block trial          task         sent     received       delay  \
# 0      1     1  Fixation dot  1.57556e+09  1.57556e+09   -0.217311
# 1      1     1   Image onset  1.57556e+09  1.57556e+09   -0.129316
# 2      1     1   Adjust task  1.57556e+09  1.57556e+09  -0.0349123
# 3      1     2  Fixation dot  1.57556e+09  1.57556e+09  -0.0383961
# 4      1     2   Image onset  1.57556e+09  1.57556e+09   -0.084779
# 5      1     2   Adjust task  1.57556e+09  1.57556e+09 -0.00626206
# 6      1     3  Fixation dot  1.57556e+09  1.57556e+09  -0.0396373
# 7      1     3   Image onset  1.57556e+09  1.57556e+09  -0.0996952
# 8      1     3   Adjust task  1.57556e+09  1.57556e+09  0.00974202
# 9      1     4  Fixation dot  1.57556e+09  1.57556e+09  -0.0195522
# 10     1     4   Image onset  1.57556e+09  1.57556e+09  -0.0485671
# 11     1     4   Adjust task  1.57556e+09  1.57556e+09 -0.00261807
# 12     1     5  Fixation dot  1.57556e+09  1.57556e+09   -0.018008
# ...

# %% [markdown]
# ## subject 15
# black screen

# %% [markdown]
# ## subject AS
# grey screen

# %% [markdown]
# ## subject CAN
# 004

# %%
timesCAN = pd.DataFrame(columns = col)
dfCAN = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectCAN/004")

# %%
#change none's to nearest numbers
for idx, num in dfCAN.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfCAN.iloc[point, 4]
            if val is not None:
                dfCAN.set_value(idx, "trial", val)
                break
#first two must be manually done
dfCAN.set_value(0, "trial", 1)
dfCAN.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfCAN.iterrows():
#14-24 trials
    if float(dfCAN.iloc[idx, 4]) > 24:
        break
    #fixation
    if float(dfCAN.iloc[idx, 4]) < 14: 
        pass
    else: 
        if dfCAN.iloc[idx, 2] == "Fixation dot":
            task = "Fixation dot"
            trial = dfCAN.iloc[idx, 4]
            block = dfCAN.iloc[idx, 0]
            sent = dfCAN.iloc[idx, 3]
            if dfCAN.iloc[idx + 1, 1] == "fix":
                received = dfCAN.iloc[idx + 1, 3]
            else:
                received = dfCAN.iloc[idx - 1, 3]
            row = [block, trial, task, sent, received]
            timesCAN.loc[len(timesCAN), :] = row
        #image onset
        elif dfCAN.iloc[idx, 2] == "Image onset":
            task = "Image onset"
            trial = dfCAN.iloc[idx, 4]
            block = dfCAN.iloc[idx, 0]
            sent = dfCAN.iloc[idx, 3]
            if dfCAN.iloc[idx + 1, 1] == "image_onset":
                received = dfCAN.iloc[idx + 1, 3]
            else:
                received = dfCAN.iloc[idx - 1, 3]        
            row = [block, trial, task, sent, received]
            timesCAN.loc[len(timesCAN), :] = row
        elif dfCAN.iloc[idx, 2] == "Adjust task":
            task = "Adjust task"
            trial = dfCAN.iloc[idx, 4]
            block = dfCAN.iloc[idx, 0]
            sent = dfCAN.iloc[idx, 3]
            if dfCAN.iloc[idx + 1, 1] == "adjust":
                received = dfCAN.iloc[idx + 1, 3]
            else:
                received = dfCAN.iloc[idx - 1, 3]
            row = [block, trial, task, sent, received]
            timesCAN.loc[len(timesCAN), :] = row
        else:
            pass

# %%
timesCAN["delay"] = timesCAN["sent"] - timesCAN["received"]

# %%
avg = timesCAN["delay"].mean()
if avg < 0:
    timesCAN["fixedlag"] = timesCAN["received"] + avg #avg was negative
elif avg > 0:
    timesCAN["fixedlag"] = timesCAN["received"] - avg

# %%
timesCAN
# Out:
#    block trial          task         sent     received        delay  \
# 0      1    14  Fixation dot  1.58387e+09  1.58387e+09    -0.169651
# 1      1    14   Image onset  1.58387e+09  1.58387e+09    -0.107494
# 2      1    14   Adjust task  1.58387e+09  1.58387e+09    -0.111602
# 3      1    15  Fixation dot  1.58387e+09  1.58387e+09    -0.183536
# 4      1    15   Image onset  1.58387e+09  1.58387e+09   -0.0471156
# 5      1    15   Adjust task  1.58387e+09  1.58387e+09   -0.0185146
# 6      1    16  Fixation dot  1.58387e+09  1.58387e+09    -0.551873
# 7      1    16   Image onset  1.58387e+09  1.58387e+09    -0.305234
# 8      1    16   Adjust task  1.58387e+09  1.58387e+09   -0.0534368
# 9      1    17  Fixation dot  1.58387e+09  1.58387e+09  -0.00464964
# 10     1    17   Image onset  1.58387e+09  1.58387e+09    -0.103793
# 11     1    17   Adjust task  1.58387e+09  1.58387e+09    0.0901484
# 12     1    18  Fixation dot  1.58387e+09  1.58387e+09   -0.0428255
# ...

# %% [markdown]
# ## subject CG

# %%
timesCG = pd.DataFrame(columns = col)
dfCG = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectCG/003")

# %%
#change none's to nearest numbers
for idx, num in dfCG.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfCG.iloc[point, 4]
            if val is not None:
                dfCG.set_value(idx, "trial", val)
                break
#first two must be manually done
dfCG.set_value(0, "trial", 1)
dfCG.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfCG.iterrows():
#10 trials
    if float(dfCG.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfCG.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfCG.iloc[idx, 4]
        block = dfCG.iloc[idx, 0]
        sent = dfCG.iloc[idx, 3]
        if dfCG.iloc[idx + 1, 1] == "fix":
            received = dfCG.iloc[idx + 1, 3]
        else:
            received = dfCG.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesCG.loc[len(timesCG), :] = row
    #image onset
    elif dfCG.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfCG.iloc[idx, 4]
        block = dfCG.iloc[idx, 0]
        sent = dfCG.iloc[idx, 3]
        if dfCG.iloc[idx + 1, 1] == "image_onset":
            received = dfCG.iloc[idx + 1, 3]
        else:
            received = dfCG.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesCG.loc[len(timesCG), :] = row
    elif dfCG.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfCG.iloc[idx, 4]
        block = dfCG.iloc[idx, 0]
        sent = dfCG.iloc[idx, 3]
        if dfCG.iloc[idx + 1, 1] == "adjust":
            received = dfCG.iloc[idx + 1, 3]
        else:
            received = dfCG.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesCG.loc[len(timesCG), :] = row
    else:
        pass

# %%
timesCG["delay"] = timesCG["sent"] - timesCG["received"]

# %%
avg = timesCG["delay"].mean()
if avg < 0:
    timesCG["fixedlag"] = timesCG["received"] + avg #avg was negative
elif avg > 0:
    timesCG["fixedlag"] = timesCG["received"] - avg

# %%
timesCG
# Out:
#    block trial          task         sent     received      delay     fixedlag
# 0      1     1  Fixation dot  1.58386e+09  1.58386e+09   -0.27266  1.58386e+09
# 1      1     1   Image onset  1.58386e+09  1.58386e+09  -0.410035  1.58386e+09
# 2      1     1   Adjust task  1.58386e+09  1.58386e+09  -0.193321  1.58386e+09
# 3      1     2  Fixation dot  1.58386e+09  1.58386e+09  -0.251293  1.58386e+09
# 4      1     2   Image onset  1.58386e+09  1.58386e+09  -0.360672  1.58386e+09
# 5      1     2   Adjust task  1.58386e+09  1.58386e+09  -0.257875  1.58386e+09
# 6      1     3  Fixation dot  1.58386e+09  1.58386e+09   -0.66969  1.58386e+09
# 7      1     3   Image onset  1.58386e+09  1.58386e+09  -0.333822  1.58386e+09
# 8      1     3   Adjust task  1.58386e+09  1.58386e+09  -0.275162  1.58386e+09
# 9      1     4  Fixation dot  1.58386e+09  1.58386e+09   -0.30266  1.58386e+09
# 10     1     4   Image onset  1.58386e+09  1.58386e+09  -0.290056  1.58386e+09
# ...

# %% [markdown]
# ## subject_EK
# 002

# %%
timesEK = pd.DataFrame(columns = col)
dfEK = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectEK/002")

# %%
#change none's to nearest numbers
for idx, num in dfEK.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfEK.iloc[point, 4]
            if val is not None:
                dfEK.set_value(idx, "trial", val)
                break
#first two must be manually done
dfEK.set_value(0, "trial", 1)
dfEK.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfEK.iterrows():
#10 trials
    if float(dfEK.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfEK.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfEK.iloc[idx, 4]
        block = dfEK.iloc[idx, 0]
        sent = dfEK.iloc[idx, 3]
        if dfEK.iloc[idx + 1, 1] == "fix":
            received = dfEK.iloc[idx + 1, 3]
        else:
            received = dfEK.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesEK.loc[len(timesEK), :] = row
    #image onset
    elif dfEK.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfEK.iloc[idx, 4]
        block = dfEK.iloc[idx, 0]
        sent = dfEK.iloc[idx, 3]
        if dfEK.iloc[idx + 1, 1] == "image_onset":
            received = dfEK.iloc[idx + 1, 3]
        else:
            received = dfEK.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesEK.loc[len(timesEK), :] = row
    elif dfEK.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfEK.iloc[idx, 4]
        block = dfEK.iloc[idx, 0]
        sent = dfEK.iloc[idx, 3]
        if dfEK.iloc[idx + 1, 1] == "adjust":
            received = dfEK.iloc[idx + 1, 3]
        else:
            received = dfEK.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesEK.loc[len(timesEK), :] = row
    else:
        pass

# %%
timesEK["delay"] = timesEK["sent"] - timesEK["received"]

# %%
avg = timesEK["delay"].mean()
if avg < 0:
    timesEK["fixedlag"] = timesEK["received"] + avg #avg was negative
elif avg > 0:
    timesEK["fixedlag"] = timesEK["received"] - avg

# %%
timesEK
# Out:
#    block trial          task         sent     received     delay     fixedlag
# 0      1     1  Fixation dot  1.58345e+09  1.58345e+09    -0.257  1.58345e+09
# 1      1     1   Image onset  1.58345e+09  1.58345e+09 -0.295732  1.58345e+09
# 2      1     1   Adjust task  1.58345e+09  1.58345e+09 -0.170138  1.58345e+09
# 3      1     2  Fixation dot  1.58345e+09  1.58345e+09 -0.233374  1.58345e+09
# 4      1     2   Image onset  1.58345e+09  1.58345e+09 -0.257987  1.58345e+09
# 5      1     2   Adjust task  1.58345e+09  1.58345e+09 -0.169469  1.58345e+09
# 6      1     3  Fixation dot  1.58345e+09  1.58345e+09 -0.203517  1.58345e+09
# 7      1     3   Image onset  1.58345e+09  1.58345e+09 -0.234626  1.58345e+09
# 8      1     3   Adjust task  1.58345e+09  1.58345e+09 -0.170361  1.58345e+09
# 9      1     4  Fixation dot  1.58345e+09  1.58345e+09 -0.183933  1.58345e+09
# 10     1     4   Image onset  1.58345e+09  1.58345e+09 -0.255517  1.58345e+09
# ...

# %% [markdown]
# ## subject ES

# %%
timesES = pd.DataFrame(columns = col)
dfES = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectES/000")

# %%
#change none's to nearest numbers
for idx, num in dfES.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfES.iloc[point, 4]
            if val is not None:
                dfES.set_value(idx, "trial", val)
                break
#first two must be manually done
dfES.set_value(0, "trial", 1)
dfES.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfES.iterrows():
#10 trials
    if float(dfES.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfES.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfES.iloc[idx, 4]
        block = dfES.iloc[idx, 0]
        sent = dfES.iloc[idx, 3]
        if dfES.iloc[idx + 1, 1] == "fix":
            received = dfES.iloc[idx + 1, 3]
        else:
            received = dfES.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesES.loc[len(timesES), :] = row
    #image onset
    elif dfES.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfES.iloc[idx, 4]
        block = dfES.iloc[idx, 0]
        sent = dfES.iloc[idx, 3]
        if dfES.iloc[idx + 1, 1] == "image_onset":
            received = dfES.iloc[idx + 1, 3]
        else:
            received = dfES.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesES.loc[len(timesES), :] = row
    elif dfES.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfES.iloc[idx, 4]
        block = dfES.iloc[idx, 0]
        sent = dfES.iloc[idx, 3]
        if dfES.iloc[idx + 1, 1] == "adjust":
            received = dfES.iloc[idx + 1, 3]
        else:
            received = dfES.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesES.loc[len(timesES), :] = row
    else:
        pass

# %%
timesES["delay"] = timesES["sent"] - timesES["received"]

# %%
avg = timesES["delay"].mean()
if avg < 0:
    timesES["fixedlag"] = timesES["received"] + avg #avg was negative
elif avg > 0:
    timesES["fixedlag"] = timesES["received"] - avg

# %%
timesES
# Out:
#    block trial          task         sent     received       delay  \
# 0      1     1  Fixation dot  1.58344e+09  1.58344e+09  -0.0305641
# 1      1     1   Image onset  1.58344e+09  1.58344e+09   -0.144589
# 2      1     1   Adjust task  1.58344e+09  1.58344e+09   0.0233212
# 3      1     2  Fixation dot  1.58344e+09  1.58344e+09  -0.0104172
# 4      1     2   Image onset  1.58344e+09  1.58344e+09  -0.0472689
# 5      1     2   Adjust task  1.58344e+09  1.58344e+09   0.0196331
# 6      1     3  Fixation dot  1.58344e+09  1.58344e+09   -0.022521
# 7      1     3   Image onset  1.58344e+09  1.58344e+09   -0.058733
# 8      1     3   Adjust task  1.58344e+09  1.58344e+09   -0.027842
# 9      1     4  Fixation dot  1.58344e+09  1.58344e+09  -0.0362771
# 10     1     4   Image onset  1.58344e+09  1.58344e+09   -0.051079
# 11     1     4   Adjust task  1.58344e+09  1.58344e+09 -0.00837088
# 12     1     5  Fixation dot  1.58344e+09  1.58344e+09   -0.024406
# ...

# %% [markdown]
# ## subject GM

# %%
timesGM = pd.DataFrame(columns = col)
dfGM = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectGM/000")

# %%
#change none's to nearest numbers
for idx, num in dfGM.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfGM.iloc[point, 4]
            if val is not None:
                dfGM.set_value(idx, "trial", val)
                break
#first two must be manually done
dfGM.set_value(0, "trial", 1)
dfGM.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfGM.iterrows():
#10 trials
    if float(dfGM.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfGM.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfGM.iloc[idx, 4]
        block = dfGM.iloc[idx, 0]
        sent = dfGM.iloc[idx, 3]
        if dfGM.iloc[idx + 1, 1] == "fix":
            received = dfGM.iloc[idx + 1, 3]
        else:
            received = dfGM.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesGM.loc[len(timesGM), :] = row
    #image onset
    elif dfGM.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfGM.iloc[idx, 4]
        block = dfGM.iloc[idx, 0]
        sent = dfGM.iloc[idx, 3]
        if dfGM.iloc[idx + 1, 1] == "image_onset":
            received = dfGM.iloc[idx + 1, 3]
        else:
            received = dfGM.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesGM.loc[len(timesGM), :] = row
    elif dfGM.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfGM.iloc[idx, 4]
        block = dfGM.iloc[idx, 0]
        sent = dfGM.iloc[idx, 3]
        if dfGM.iloc[idx + 1, 1] == "adjust":
            received = dfGM.iloc[idx + 1, 3]
        else:
            received = dfGM.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesGM.loc[len(timesGM), :] = row
    else:
        pass

# %%
timesGM["delay"] = timesGM["sent"] - timesGM["received"]

# %%
avg = timesGM["delay"].mean()
if avg < 0:
    timesGM["fixedlag"] = timesGM["received"] + avg #avg was negative
elif avg > 0:
    timesGM["fixedlag"] = timesGM["received"] - avg

# %%
timesGM
# Out:
#    block trial          task         sent     received     delay     fixedlag
# 0      1     1  Fixation dot  1.58345e+09  1.58345e+09 -0.386984  1.58345e+09
# 1      1     1   Image onset  1.58345e+09  1.58345e+09  -0.49289  1.58345e+09
# 2      1     1   Adjust task  1.58345e+09  1.58345e+09 -0.332677  1.58345e+09
# 3      1     2  Fixation dot  1.58345e+09  1.58345e+09 -0.373715  1.58345e+09
# 4      1     2   Image onset  1.58345e+09  1.58345e+09 -0.420334  1.58345e+09
# 5      1     2   Adjust task  1.58345e+09  1.58345e+09 -0.361653  1.58345e+09
# 6      1     3  Fixation dot  1.58345e+09  1.58345e+09 -0.428786  1.58345e+09
# 7      1     3   Image onset  1.58345e+09  1.58345e+09  0.941438  1.58345e+09
# 8      1     3   Adjust task  1.58345e+09  1.58345e+09 -0.316686  1.58345e+09
# 9      1     4  Fixation dot  1.58345e+09  1.58345e+09 -0.357911  1.58345e+09
# 10     1     4   Image onset  1.58345e+09  1.58345e+09 -0.427019  1.58345e+09
# ...

# %% [markdown]
# ## subject HE

# %%
timesHE = pd.DataFrame(columns = col)
dfHE = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectHE/000")

# %%
#change none's to nearest numbers
for idx, num in dfHE.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfHE.iloc[point, 4]
            if val is not None:
                dfHE.set_value(idx, "trial", val)
                break
#first two must be manually done
dfHE.set_value(0, "trial", 1)
dfHE.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfHE.iterrows():
#10 trials
    if float(dfHE.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfHE.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfHE.iloc[idx, 4]
        block = dfHE.iloc[idx, 0]
        sent = dfHE.iloc[idx, 3]
        if dfHE.iloc[idx + 1, 1] == "fix":
            received = dfHE.iloc[idx + 1, 3]
        else:
            received = dfHE.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesHE.loc[len(timesHE), :] = row
    #image onset
    elif dfHE.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfHE.iloc[idx, 4]
        block = dfHE.iloc[idx, 0]
        sent = dfHE.iloc[idx, 3]
        if dfHE.iloc[idx + 1, 1] == "image_onset":
            received = dfHE.iloc[idx + 1, 3]
        else:
            received = dfHE.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesHE.loc[len(timesHE), :] = row
    elif dfHE.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfHE.iloc[idx, 4]
        block = dfHE.iloc[idx, 0]
        sent = dfHE.iloc[idx, 3]
        if dfHE.iloc[idx + 1, 1] == "adjust":
            received = dfHE.iloc[idx + 1, 3]
        else:
            received = dfHE.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesHE.loc[len(timesHE), :] = row
    else:
        pass

# %%
timesHE["delay"] = timesHE["sent"] - timesHE["received"]

# %%
avg = timesHE["delay"].mean()
if avg < 0:
    timesHE["fixedlag"] = timesHE["received"] + avg #avg was negative
elif avg > 0:
    timesHE["fixedlag"] = timesHE["received"] - avg

# %%
timesHE
# Out:
#    block trial          task         sent     received        delay  \
# 0      1     1  Fixation dot  1.58345e+09  1.58345e+09   -0.0489469
# 1      1     1   Image onset  1.58345e+09  1.58345e+09    -0.122509
# 2      1     1   Adjust task  1.58345e+09  1.58345e+09  -0.00145698
# 3      1     2  Fixation dot  1.58345e+09  1.58345e+09   -0.0223382
# 4      1     2   Image onset  1.58345e+09  1.58345e+09    -0.104125
# 5      1     2   Adjust task  1.58345e+09  1.58345e+09   0.00614381
# 6      1     3  Fixation dot  1.58345e+09  1.58345e+09   -0.0300848
# 7      1     3   Image onset  1.58345e+09  1.58345e+09     -0.08095
# 8      1     3   Adjust task  1.58345e+09  1.58345e+09  0.000928879
# 9      1     4  Fixation dot  1.58345e+09  1.58345e+09    -0.044301
# 10     1     4   Image onset  1.58345e+09  1.58345e+09    -0.048022
# 11     1     4   Adjust task  1.58345e+09  1.58345e+09   0.00328898
# 12     1     5  Fixation dot  1.58345e+09  1.58345e+09   -0.0189571
# ...

# %% [markdown]
# ## subject HL

# %%
timesHL = pd.DataFrame(columns = col)
dfHL = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectHL/001")

# %%
#change none's to nearest numbers
for idx, num in dfHL.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfHL.iloc[point, 4]
            if val is not None:
                dfHL.set_value(idx, "trial", val)
                break
#first two must be manually done
dfHL.set_value(0, "trial", 1)
dfHL.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfHL.iterrows():
#10 trials
    if float(dfHL.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfHL.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfHL.iloc[idx, 4]
        block = dfHL.iloc[idx, 0]
        sent = dfHL.iloc[idx, 3]
        if dfHL.iloc[idx + 1, 1] == "fix":
            received = dfHL.iloc[idx + 1, 3]
        else:
            received = dfHL.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesHL.loc[len(timesHL), :] = row
    #image onset
    elif dfHL.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfHL.iloc[idx, 4]
        block = dfHL.iloc[idx, 0]
        sent = dfHL.iloc[idx, 3]
        if dfHL.iloc[idx + 1, 1] == "image_onset":
            received = dfHL.iloc[idx + 1, 3]
        else:
            received = dfHL.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesHL.loc[len(timesHL), :] = row
    elif dfHL.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfHL.iloc[idx, 4]
        block = dfHL.iloc[idx, 0]
        sent = dfHL.iloc[idx, 3]
        if dfHL.iloc[idx + 1, 1] == "adjust":
            received = dfHL.iloc[idx + 1, 3]
        else:
            received = dfHL.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesHL.loc[len(timesHL), :] = row
    else:
        pass

# %%
timesHL["delay"] = timesHL["sent"] - timesHL["received"]

# %%
avg = timesHL["delay"].mean()
if avg < 0:
    timesHL["fixedlag"] = timesHL["received"] + avg #avg was negative
elif avg > 0:
    timesHL["fixedlag"] = timesHL["received"] - avg

# %%
timesHL
# Out:
#    block trial          task         sent     received       delay  \
# 0      1     1  Fixation dot  1.58378e+09  1.58378e+09   -0.164127
# 1      1     1   Image onset  1.58378e+09  1.58378e+09   -0.148792
# 2      1     1   Adjust task  1.58378e+09  1.58378e+09  -0.0986552
# 3      1     2  Fixation dot  1.58378e+09  1.58378e+09  -0.0450132
# 4      1     2   Image onset  1.58378e+09  1.58378e+09   -0.128946
# 5      1     2   Adjust task  1.58378e+09  1.58378e+09  0.00123382
# 6      1     3  Fixation dot  1.58378e+09  1.58378e+09   -0.144839
# 7      1     3   Image onset  1.58378e+09  1.58378e+09   -0.256373
# 8      1     3   Adjust task  1.58378e+09  1.58378e+09   -0.101945
# 9      1     4  Fixation dot  1.58378e+09  1.58378e+09   -0.116316
# 10     1     4   Image onset  1.58378e+09  1.58378e+09   -0.114221
# 11     1     4   Adjust task  1.58378e+09  1.58378e+09  -0.0699182
# 12     1     5  Fixation dot  1.58378e+09  1.58378e+09  -0.0578551
# ...

# %% [markdown]
# ## subject HY

# %%
timesHY = pd.DataFrame(columns = col)
dfHY = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectHY/002")

# %%
#change none's to nearest numbers
for idx, num in dfHY.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfHY.iloc[point, 4]
            if val is not None:
                dfHY.set_value(idx, "trial", val)
                break
#first two must be manually done
dfHY.set_value(0, "trial", 1)
dfHY.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfHY.iterrows():
#10 trials
    if float(dfHY.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfHY.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfHY.iloc[idx, 4]
        block = dfHY.iloc[idx, 0]
        sent = dfHY.iloc[idx, 3]
        if dfHY.iloc[idx + 1, 1] == "fix":
            received = dfHY.iloc[idx + 1, 3]
        else:
            received = dfHY.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesHY.loc[len(timesHY), :] = row
    #image onset
    elif dfHY.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfHY.iloc[idx, 4]
        block = dfHY.iloc[idx, 0]
        sent = dfHY.iloc[idx, 3]
        if dfHY.iloc[idx + 1, 1] == "image_onset":
            received = dfHY.iloc[idx + 1, 3]
        else:
            received = dfHY.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesHY.loc[len(timesHY), :] = row
    elif dfHY.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfHY.iloc[idx, 4]
        block = dfHY.iloc[idx, 0]
        sent = dfHY.iloc[idx, 3]
        if dfHY.iloc[idx + 1, 1] == "adjust":
            received = dfHY.iloc[idx + 1, 3]
        else:
            received = dfHY.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesHY.loc[len(timesHY), :] = row
    else:
        pass

# %%
timesHY["delay"] = timesHY["sent"] - timesHY["received"]

# %%
avg = timesHY["delay"].mean()
if avg < 0:
    timesHY["fixedlag"] = timesHY["received"] + avg #avg was negative
elif avg > 0:
    timesHY["fixedlag"] = timesHY["received"] - avg

# %%
timesHY
# Out:
#    block trial          task         sent     received      delay     fixedlag
# 0      1     1  Fixation dot  1.58386e+09  1.58386e+09  -0.107679  1.58386e+09
# 1      1     1   Image onset  1.58386e+09  1.58386e+09  -0.176453  1.58386e+09
# 2      1     1   Adjust task  1.58386e+09  1.58386e+09  -0.129341  1.58386e+09
# 3      1     2  Fixation dot  1.58386e+09  1.58386e+09 -0.0473714  1.58386e+09
# 4      1     2   Image onset  1.58386e+09  1.58386e+09  -0.167465  1.58386e+09
# 5      1     2   Adjust task  1.58386e+09  1.58386e+09 -0.0998583  1.58386e+09
# 6      1     3  Fixation dot  1.58386e+09  1.58386e+09 -0.0490742  1.58386e+09
# 7      1     3   Image onset  1.58386e+09  1.58386e+09  -0.116029  1.58386e+09
# 8      1     3   Adjust task  1.58386e+09  1.58386e+09 -0.0682726  1.58386e+09
# 9      1     4  Fixation dot  1.58386e+09  1.58386e+09  -0.112765  1.58386e+09
# 10     1     4   Image onset  1.58386e+09  1.58386e+09  -0.163527  1.58386e+09
# ...

# %% [markdown]
# ## subject SA

# %%
timesSA = pd.DataFrame(columns = col)
dfSA = load_manual_annotations("/Users/selenazhang 1/Desktop/eyedata/subjectSA/000")

# %%
#change none's to nearest numbers
for idx, num in dfSA.iloc[:, 4].items():
    if num == None:
        point = idx
        while point >= 0:
            #finds the nearest filled cell that is before it
            point -= 1
            val = dfSA.iloc[point, 4]
            if val is not None:
                dfSA.set_value(idx, "trial", val)
                break
#first two must be manually done
dfSA.set_value(0, "trial", 1)
dfSA.set_value(1, "trial", 1);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for idx, event in dfSA.iterrows():
#10 trials
    if float(dfSA.iloc[idx, 4]) > 10:
        break
    #fixation
    if dfSA.iloc[idx, 2] == "Fixation dot":
        task = "Fixation dot"
        trial = dfSA.iloc[idx, 4]
        block = dfSA.iloc[idx, 0]
        sent = dfSA.iloc[idx, 3]
        if dfSA.iloc[idx + 1, 1] == "fix":
            received = dfSA.iloc[idx + 1, 3]
        else:
            received = dfSA.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesSA.loc[len(timesSA), :] = row
    #image onset
    elif dfSA.iloc[idx, 2] == "Image onset":
        task = "Image onset"
        trial = dfSA.iloc[idx, 4]
        block = dfSA.iloc[idx, 0]
        sent = dfSA.iloc[idx, 3]
        if dfSA.iloc[idx + 1, 1] == "image_onset":
            received = dfSA.iloc[idx + 1, 3]
        else:
            received = dfSA.iloc[idx - 1, 3]        
        row = [block, trial, task, sent, received]
        timesSA.loc[len(timesSA), :] = row
    elif dfSA.iloc[idx, 2] == "Adjust task":
        task = "Adjust task"
        trial = dfSA.iloc[idx, 4]
        block = dfSA.iloc[idx, 0]
        sent = dfSA.iloc[idx, 3]
        if dfSA.iloc[idx + 1, 1] == "adjust":
            received = dfSA.iloc[idx + 1, 3]
        else:
            received = dfSA.iloc[idx - 1, 3]
        row = [block, trial, task, sent, received]
        timesSA.loc[len(timesSA), :] = row
    else:
        pass

# %%
timesSA["delay"] = timesSA["sent"] - timesSA["received"]

# %%
avg = timesSA["delay"].mean()
if avg < 0:
    timesSA["fixedlag"] = timesSA["received"] + avg #avg was negative
elif avg > 0:
    timesSA["fixedlag"] = timesSA["received"] - avg

# %%
timesSA
# Out:
#    block trial          task         sent     received       delay  \
# 0      1     1  Fixation dot  1.58352e+09  1.58352e+09  -0.0263267
# 1      1     1   Image onset  1.58352e+09  1.58352e+09   -0.176791
# 2      1     1   Adjust task  1.58352e+09  1.58352e+09  -0.0356007
# 3      1     2  Fixation dot  1.58352e+09  1.58352e+09  -0.0574036
# 4      1     2   Image onset  1.58352e+09  1.58352e+09   -0.100789
# 5      1     2   Adjust task  1.58352e+09  1.58352e+09 -0.00957441
# 6      1     3  Fixation dot  1.58352e+09  1.58352e+09  -0.0841627
# 7      1     3   Image onset  1.58352e+09  1.58352e+09    -0.21141
# 8      1     3   Adjust task  1.58352e+09  1.58352e+09  -0.0558066
# 9      1     4  Fixation dot  1.58352e+09  1.58352e+09  -0.0606196
# 10     1     4   Image onset  1.58352e+09  1.58352e+09  -0.0759706
# 11     1     4   Adjust task  1.58352e+09  1.58352e+09  -0.0136497
# 12     1     5  Fixation dot  1.58352e+09  1.58352e+09  -0.0737007
# ...
